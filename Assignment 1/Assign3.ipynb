# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("tyre_data_hackathon.csv")
data
# Out:
#      Tyre Life Span (Years)  Tyre Life in Kilometers  Tyre Width  \
# 0                         3                    41993         215
# 1                         5                    65083         165
# 2                         3                    68282         195
# 3                         6                    65944         195
# 4                         7                    39770         225
# ..                      ...                      ...         ...
# 995                       5                    48220         225
# 996                       5                    40332         185
# 997                       5                    42301         205
# 998                       6                    39851         205
# 999                       3                    39932         175
#
#      Required Tyre Pressure  Maximum Safe Tyre Speed Tyre Brand/Company  \
# 0                        30                      220            Pirelli
# ...

# %%
data.columns
# Out:
# Index(['Tyre Life Span (Years)', 'Tyre Life in Kilometers', 'Tyre Width',
#        'Required Tyre Pressure', 'Maximum Safe Tyre Speed',
#        'Tyre Brand/Company', 'Tyre Load Capacity (kg)', 'Tyre Position',
#        'Tread Depth (mm)', 'Tyre Temperature (°C)', 'Tyre Type',
#        'Seasonal Type', 'Speed Index', 'Load Index', 'Manufacturing Date',
#        'Wheel Alignment History', 'Road Condition Usage', 'Last Rotation Date',
#        'Vehicle Type Compatibility', 'Tyre Noise Level (dB)', 'TPMS Pressure',
#        'TPMS Temperature', 'Leak Detection', 'Tread Wear Pattern',
#        'Mileage Since Installation', 'Expected Replacement Date'],
#       dtype='object')

# %%
data = data.drop('Last Rotation Date', axis=1)

# %%
data
# Out:
#      Tyre Life Span (Years)  Tyre Life in Kilometers  Tyre Width  \
# 0                         3                    41993         215
# 1                         5                    65083         165
# 2                         3                    68282         195
# 3                         6                    65944         195
# 4                         7                    39770         225
# ..                      ...                      ...         ...
# 995                       5                    48220         225
# 996                       5                    40332         185
# 997                       5                    42301         205
# 998                       6                    39851         205
# 999                       3                    39932         175
#
#      Required Tyre Pressure  Maximum Safe Tyre Speed Tyre Brand/Company  \
# 0                        30                      220            Pirelli
# ...

# %%
data.duplicated(subset=['Tyre Width']).sum()
# Out:
# np.int64(993)

# %%
pie_data = data['Tyre Width'].value_counts()
pie_data.plot.pie(autopct='%1.1f%%', figsize=(4,4))
plt.title('Distribution by Category') 
plt.show()

# %%
road_counts = df['Road Condition Usage'].value_counts()

plt.figure(figsize=(6,4))
road_counts.plot(kind='bar', color='skyblue', edgecolor='black')

plt.title('Tyre Usage by Road Condition')
plt.xlabel('Road Condition Type')
plt.ylabel('Number of Tyres')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)

# Add value labels on top of bars
for i, v in enumerate(road_counts):
    plt.text(i, v+0.5, str(v), ha='center')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 road_counts = df['Road Condition Usage'].value_counts()
#       3 plt.figure(figsize=(6,4))
#       4 road_counts.plot(kind='bar', color='skyblue', edgecolor='black')
#
# NameError: name 'df' is not defined
